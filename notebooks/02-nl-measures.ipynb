# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext watermark
# %watermark -v -n -m -p numpy,scipy,sklearn,pandas
# Out:
# Fri Oct 12 2018
#
# CPython 3.6.6
# IPython 6.5.0
#
# numpy 1.15.1
# scipy 1.1.0
# sklearn 0.19.1
# pandas 0.23.4
#
# compiler   : GCC 4.8.2 20140120 (Red Hat 4.8.2-15)
# system     : Linux
# release    : 4.15.0-36-generic
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 4
# interpreter: 64bit

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import os

PROJ_ROOT = os.path.abspath(os.path.join(os.pardir))
DATA_ROOT = os.path.abspath(os.path.join(PROJ_ROOT, 'data'))
PROCESSED_ROOT = os.path.abspath(os.path.join(DATA_ROOT, 'processed'))
RAW_ROOT = os.path.abspath(os.path.join(DATA_ROOT, 'raw'))
LABELED_ROOT = os.path.abspath(os.path.join(DATA_ROOT, 'labeled'))
DURATIONS_ROOT = os.path.abspath(os.path.join(DATA_ROOT, 'durations'))
print(PROJ_ROOT)
print(DATA_ROOT)
print(PROCESSED_ROOT)
import sys
sys.path.append(os.path.join(PROJ_ROOT, 'src'))
# Out:
# /home/miroslav/Source/thesis_project
# /home/miroslav/Source/thesis_project/data
# /home/miroslav/Source/thesis_project/data/processed

# %%
import nolds
import data
import mne
CHANNEL_NAMES = ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2',
                 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz']

# %%
file_name = '1a.fif'
raw_fif = mne.io.read_raw_fif(os.path.join(PROCESSED_ROOT, file_name))
t = pd.DataFrame(raw_fif.get_data())
data = pd.DataFrame(np.transpose(t.values), columns=CHANNEL_NAMES)
data = np.transpose(data.values)
# Out:
# Opening raw data file /home/kovar/source/thesis_project/data/processed/1a.fif...
# This filename (/home/kovar/source/thesis_project/data/processed/1a.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
# Isotrak not found
#     Read a total of 1 projection items:
#         Average EEG reference (1 x 19) active
#     Range : 0 ... 19104 =      0.000 ...    76.416 secs
# Ready.
# <ipython-input-9-535bbf6019f8>:2: RuntimeWarning: This filename (/home/kovar/source/thesis_project/data/processed/1a.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz or raw_tsss.fif.gz
#   raw_fif = mne.io.read_raw_fif(os.path.join(PROCESSED_ROOT, file_name))

# %%
len(data[0])
# Out:
# 19105

# %%
nolds.lyap_r(data[0])
# Out:
# /home/kovar/.local/lib/python3.6/site-packages/nolds/measures.py:248: RuntimeWarning: signal has very low mean frequency, setting min_tsep = 4776
#   warnings.warn(msg.format(min_tsep), RuntimeWarning)
# /home/kovar/.local/lib/python3.6/site-packages/nolds/measures.py:31: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(np.sum((x - y)**2, axis=1))
# 0.02927115109928854

# %%
n = len(data[0])
for i in range(4):
    nolds.lyap_r(data[0][i*(n//4), (i+1)*(n//4)])

# %%
META_COLUMN_NAMES = ['freq', 'RESP_4W', 'RESP_FIN', 'REMISE_FIN', 'AGE', 'SEX', 'M_1',
       'M_4', 'M_F', 'délka léčby', 'lék 1', 'lék 2', 'lék 3', 'lék 4']
META_FILE_NAME = 'DEP-POOL_Final_144.xlsx'
meta_df = pd.read_excel(os.path.join(RAW_ROOT, META_FILE_NAME), index_col='ID', names=META_COLUMN_NAMES)
s = sorted(meta_df['M_1'].values + meta_df['M_4'].values)

# %%
file_name = 'splits.pickle'
df = pd.read_pickle(os.path.join(LABELED_ROOT, file_name))
df
# Out:
# feature             lyap                                             corr  \
# chunk                  0          1          2          3    4          0
# trial channel
# a-81  FP1      0.0332509  0.0320839  0.0344884  0.0301706  NaN    0.13651
#       FP2      0.0200796  0.0335107  0.0329874  0.0326068  NaN   0.219099
#       F3       0.0333025  0.0285505  0.0338725  0.0285498  NaN    0.21272
#       F4       0.0279521  0.0259075  0.0310387  0.0261802  NaN  0.0559961
#       C3       0.0309839  0.0293103  0.0346967  0.0259656  NaN   0.272971
#       C4         0.04057  0.0420812  0.0412538  0.0393642  NaN   0.091858
#       P3       0.0350301  0.0318987   0.033705  0.0348287  NaN    0.35026
#       P4        0.030147  0.0293618   0.031835  0.0314277  NaN  0.0718656
#       O1       0.0349762  0.0342467  0.0354309  0.0340181  NaN    1.12025
#       O2       0.0367729  0.0364496  0.0354242  0.0342836  NaN   0.810315
#       F7       0.0290483  0.0315079  0.0173254  0.0305919  NaN  0.0414261
#       F8       0.0387092  0.0389368   0.027487  0.0224021  NaN  0.0219985
#       T3       0.0296761  0.0303569  0.0323872  0.0305863  NaN  0.0652044
#       T4       0.0378344  0.0353512  0.0386251  0.0224912  NaN    0.06649
#       T5       0.0327041  0.0299582  0.0331343  0.0306854  NaN     0.3283
#       T6       0.0292903   0.024589  0.0306183    0.03482  NaN   0.235574
#       Fz       0.0336667  0.0316345  0.0328524   0.033983  NaN   0.723832
#       Cz       0.0297777  0.0294085  0.0300422  0.0314861  NaN    0.15334
#       Pz       0.0348543  0.0320751  0.0328013  0.0349163  NaN    2.49204
# a-16  FP1      0.0278505  0.0268718  0.0275671  0.0261925  NaN   0.236171
#       FP2      0.0280212   0.026834  0.0274645  0.0272418  NaN   0.448669
#       F3       0.0290398  0.0296688  0.0302281  0.0277146  NaN   0.390085
#       F4       0.0285831  0.0266668  0.0289093   0.028654  NaN   0.251642
#       C3       0.0456577  0.0455289  0.0458099   0.033636  NaN   0.193563
#       C4       0.0290563  0.0288176   0.042662  0.0434338  NaN   0.215249
#       P3       0.0441032  0.0300944  0.0318346  0.0296438  NaN   0.252643
#       P4       0.0331738  0.0302372   0.028956    0.02965  NaN   0.245778
#       O1       0.0289409  0.0308851  0.0323545  0.0326528  NaN    1.07083
#       O2        0.031998  0.0332276  0.0301388   0.029125  NaN    1.70544
#       F7       0.0283103  0.0291304  0.0299895  0.0312831  NaN   0.173722
# ...                  ...        ...        ...        ...  ...        ...
# b-100 O1             NaN        NaN        NaN        NaN  NaN        NaN
#       O2             NaN        NaN        NaN        NaN  NaN        NaN
#       F7             NaN        NaN        NaN        NaN  NaN        NaN
#       F8             NaN        NaN        NaN        NaN  NaN        NaN
#       T3             NaN        NaN        NaN        NaN  NaN        NaN
#       T4             NaN        NaN        NaN        NaN  NaN        NaN
#       T5             NaN        NaN        NaN        NaN  NaN        NaN
#       T6             NaN        NaN        NaN        NaN  NaN        NaN
#       Fz             NaN        NaN        NaN        NaN  NaN        NaN
#       Cz             NaN        NaN        NaN        NaN  NaN        NaN
#       Pz             NaN        NaN        NaN        NaN  NaN        NaN
# a-12  FP1            NaN        NaN        NaN        NaN  NaN        NaN
#       FP2            NaN        NaN        NaN        NaN  NaN        NaN
#       F3             NaN        NaN        NaN        NaN  NaN        NaN
#       F4             NaN        NaN        NaN        NaN  NaN        NaN
#       C3             NaN        NaN        NaN        NaN  NaN        NaN
#       C4             NaN        NaN        NaN        NaN  NaN        NaN
#       P3             NaN        NaN        NaN        NaN  NaN        NaN
#       P4             NaN        NaN        NaN        NaN  NaN        NaN
#       O1             NaN        NaN        NaN        NaN  NaN        NaN
#       O2             NaN        NaN        NaN        NaN  NaN        NaN
#       F7             NaN        NaN        NaN        NaN  NaN        NaN
#       F8             NaN        NaN        NaN        NaN  NaN        NaN
#       T3             NaN        NaN        NaN        NaN  NaN        NaN
#       T4             NaN        NaN        NaN        NaN  NaN        NaN
#       T5             NaN        NaN        NaN        NaN  NaN        NaN
#       T6             NaN        NaN        NaN        NaN  NaN        NaN
#       Fz             NaN        NaN        NaN        NaN  NaN        NaN
#       Cz             NaN        NaN        NaN        NaN  NaN        NaN
#       Pz             NaN        NaN        NaN        NaN  NaN        NaN
#
# feature                                                   dfa            \
# chunk                  1          2          3    4         0         1
# trial channel
# a-81  FP1       0.299763   0.181938    0.25152  NaN  0.959384  0.968109
#       FP2        0.33426    0.29156    0.31579  NaN   1.01362   1.03612
#       F3        0.220983    0.19202  0.0842292  NaN  0.823248  0.986883
#       F4       0.0752787  0.0378794  0.0552373  NaN   1.00197  0.862625
#       C3       0.0749763   0.252762  0.0601839  NaN  0.774205   0.81657
#       C4       0.0343815  0.0463477  0.0981841  NaN  0.552354  0.839836
#       P3        0.536624   0.523682   0.686926  NaN  0.610404  0.427324
#       P4        0.175358   0.139907   0.272637  NaN  0.688047   1.01092
#       O1         1.15891     1.0337     1.5373  NaN  0.918266  0.611544
#       O2        0.753583    1.09021    2.18254  NaN   1.02528  0.794545
#       F7       0.0776463   0.186992  0.0815269  NaN  0.960791   1.03347
#       F8       0.0725729  0.0785547  0.0484524  NaN  0.962629  0.988386
#       T3       0.0214513   0.186761   0.138942  NaN  0.865525   0.94985
#       T4       0.0322876  0.0432997  0.0600846  NaN  0.903113  0.855988
#       T5       0.0839897   0.245188    0.16346  NaN  0.933981  0.779776
#       T6       0.0929116   0.118245   0.477235  NaN  0.967192   0.74704
#       Fz        0.698154   0.547538   0.686871  NaN  0.891823  0.864914
#       Cz        0.137759   0.147181   0.208981  NaN  0.765015   0.93247
#       Pz        0.860357   0.442182    1.61703  NaN  0.465584  0.604913
# a-16  FP1       0.265752   0.114211   0.313903  NaN  0.792748   1.01818
#       FP2       0.339508   0.179074   0.277244  NaN   0.93345  0.988935
#       F3        0.235675   0.352831   0.340083  NaN  0.729078  0.924409
#       F4        0.245702   0.193254   0.315632  NaN  0.693735  0.662644
#       C3        0.124003   0.220518   0.260428  NaN  0.802314  0.723772
#       C4        0.122184   0.108256   0.153692  NaN  0.956399  0.772324
#       P3          0.2557   0.247688   0.344965  NaN  0.717462  0.790131
#       P4        0.413171   0.529027    0.38243  NaN  0.812857  0.910771
#       O1         1.57371    1.02547    1.88887  NaN  0.658968  0.363372
#       O2         1.06739     1.3811    1.48848  NaN  0.621625   0.43646
#       F7        0.512219   0.352575   0.392178  NaN    1.0086   1.01663
# ...                  ...        ...        ...  ...       ...       ...
# b-100 O1             NaN        NaN        NaN  NaN       NaN       NaN
#       O2             NaN        NaN        NaN  NaN       NaN       NaN
#       F7             NaN        NaN        NaN  NaN       NaN       NaN
#       F8             NaN        NaN        NaN  NaN       NaN       NaN
#       T3             NaN        NaN        NaN  NaN       NaN       NaN
#       T4             NaN        NaN        NaN  NaN       NaN       NaN
#       T5             NaN        NaN        NaN  NaN       NaN       NaN
#       T6             NaN        NaN        NaN  NaN       NaN       NaN
#       Fz             NaN        NaN        NaN  NaN       NaN       NaN
#       Cz             NaN        NaN        NaN  NaN       NaN       NaN
#       Pz             NaN        NaN        NaN  NaN       NaN       NaN
# a-12  FP1            NaN        NaN        NaN  NaN       NaN       NaN
#       FP2            NaN        NaN        NaN  NaN       NaN       NaN
#       F3             NaN        NaN        NaN  NaN       NaN       NaN
#       F4             NaN        NaN        NaN  NaN       NaN       NaN
#       C3             NaN        NaN        NaN  NaN       NaN       NaN
#       C4             NaN        NaN        NaN  NaN       NaN       NaN
#       P3             NaN        NaN        NaN  NaN       NaN       NaN
#       P4             NaN        NaN        NaN  NaN       NaN       NaN
#       O1             NaN        NaN        NaN  NaN       NaN       NaN
#       O2             NaN        NaN        NaN  NaN       NaN       NaN
#       F7             NaN        NaN        NaN  NaN       NaN       NaN
#       F8             NaN        NaN        NaN  NaN       NaN       NaN
#       T3             NaN        NaN        NaN  NaN       NaN       NaN
#       T4             NaN        NaN        NaN  NaN       NaN       NaN
#       T5             NaN        NaN        NaN  NaN       NaN       NaN
#       T6             NaN        NaN        NaN  NaN       NaN       NaN
#       Fz             NaN        NaN        NaN  NaN       NaN       NaN
#       Cz             NaN        NaN        NaN  NaN       NaN       NaN
#       Pz             NaN        NaN        NaN  NaN       NaN       NaN
#
# feature                                    hurst                      \
# chunk                 2         3    4         0         1         2
# trial channel
# a-81  FP1       1.00655   1.01968  NaN   0.59862  0.631563   0.67697
#       FP2       1.02841  0.997242  NaN  0.641163  0.611157  0.682507
#       F3       0.715707  0.895303  NaN  0.511182  0.585087  0.558214
#       F4       0.974283    0.9344  NaN  0.614371  0.594798  0.635663
#       C3       0.868866  0.640873  NaN  0.468945  0.487881  0.447134
#       C4       0.702615  0.652368  NaN  0.514168  0.583333  0.507872
#       P3       0.657987  0.520045  NaN  0.441006  0.430294  0.481962
#       P4       0.874217   0.82761  NaN  0.523105  0.655544  0.611559
#       O1       0.549962  0.612232  NaN  0.559433  0.444784  0.473308
#       O2        0.84823  0.660317  NaN  0.549328  0.522583  0.544481
#       F7        1.12296  0.961578  NaN  0.646924  0.737952  0.740833
#       F8        1.04407  0.998422  NaN  0.695703  0.712662  0.769898
#       T3        0.91269   1.01635  NaN  0.613406  0.671571  0.613527
#       T4       0.882057  0.862153  NaN  0.635502  0.580076  0.609013
#       T5       0.839886  0.974922  NaN  0.599924  0.548728  0.525092
#       T6       0.739519  0.952861  NaN   0.60349  0.553734  0.582369
#       Fz       0.872834  0.723977  NaN  0.530978  0.550548  0.482368
#       Cz       0.857788  0.875254  NaN  0.537289  0.636247  0.567686
#       Pz       0.676845  0.443642  NaN  0.463646  0.503777  0.496841
# a-16  FP1      0.960082  0.972123  NaN  0.573475  0.566523  0.606324
#       FP2      0.981883  0.867824  NaN  0.509636  0.585503  0.601032
#       F3       0.961608  0.759421  NaN  0.527781  0.587796  0.624002
#       F4       0.859383   0.83509  NaN   0.53543  0.485292  0.570406
#       C3       0.756376  0.928086  NaN  0.583108  0.528858  0.563166
#       C4       0.841697  0.923359  NaN  0.602925  0.612885  0.588317
#       P3       0.739051  0.753646  NaN  0.524311  0.605994  0.513844
#       P4       0.686481  0.639938  NaN   0.55959  0.554478  0.584018
#       O1         0.6715  0.656492  NaN  0.486031  0.398269  0.513237
#       O2       0.662473  0.649192  NaN  0.494679  0.448534  0.443808
#       F7         1.0111   1.00826  NaN  0.659353  0.673435  0.666494
# ...                 ...       ...  ...       ...       ...       ...
# b-100 O1            NaN       NaN  NaN       NaN       NaN       NaN
#       O2            NaN       NaN  NaN       NaN       NaN       NaN
#       F7            NaN       NaN  NaN       NaN       NaN       NaN
#       F8            NaN       NaN  NaN       NaN       NaN       NaN
#       T3            NaN       NaN  NaN       NaN       NaN       NaN
#       T4            NaN       NaN  NaN       NaN       NaN       NaN
#       T5            NaN       NaN  NaN       NaN       NaN       NaN
#       T6            NaN       NaN  NaN       NaN       NaN       NaN
#       Fz            NaN       NaN  NaN       NaN       NaN       NaN
#       Cz            NaN       NaN  NaN       NaN       NaN       NaN
#       Pz            NaN       NaN  NaN       NaN       NaN       NaN
# a-12  FP1           NaN       NaN  NaN       NaN       NaN       NaN
#       FP2           NaN       NaN  NaN       NaN       NaN       NaN
#       F3            NaN       NaN  NaN       NaN       NaN       NaN
#       F4            NaN       NaN  NaN       NaN       NaN       NaN
#       C3            NaN       NaN  NaN       NaN       NaN       NaN
#       C4            NaN       NaN  NaN       NaN       NaN       NaN
#       P3            NaN       NaN  NaN       NaN       NaN       NaN
#       P4            NaN       NaN  NaN       NaN       NaN       NaN
#       O1            NaN       NaN  NaN       NaN       NaN       NaN
#       O2            NaN       NaN  NaN       NaN       NaN       NaN
#       F7            NaN       NaN  NaN       NaN       NaN       NaN
#       F8            NaN       NaN  NaN       NaN       NaN       NaN
#       T3            NaN       NaN  NaN       NaN       NaN       NaN
#       T4            NaN       NaN  NaN       NaN       NaN       NaN
#       T5            NaN       NaN  NaN       NaN       NaN       NaN
#       T6            NaN       NaN  NaN       NaN       NaN       NaN
#       Fz            NaN       NaN  NaN       NaN       NaN       NaN
#       Cz            NaN       NaN  NaN       NaN       NaN       NaN
#       Pz            NaN       NaN  NaN       NaN       NaN       NaN
#
# feature
# chunk                 3    4
# trial channel
# a-81  FP1      0.634669  NaN
#       FP2      0.656424  NaN
#       F3       0.585296  NaN
#       F4        0.63495  NaN
#       C3        0.53327  NaN
#       C4       0.516286  NaN
#       P3       0.430478  NaN
#       P4       0.602904  NaN
#       O1       0.514594  NaN
#       O2       0.515307  NaN
#       F7       0.674244  NaN
#       F8       0.705975  NaN
#       T3       0.690378  NaN
#       T4       0.627199  NaN
#       T5       0.584387  NaN
#       T6        0.60671  NaN
#       Fz       0.497164  NaN
#       Cz       0.634333  NaN
#       Pz       0.512141  NaN
# a-16  FP1      0.627209  NaN
#       FP2      0.551031  NaN
#       F3       0.559477  NaN
#       F4       0.612999  NaN
#       C3       0.517819  NaN
#       C4       0.582307  NaN
#       P3       0.575144  NaN
#       P4        0.60931  NaN
#       O1        0.43226  NaN
#       O2       0.510535  NaN
#       F7        0.63579  NaN
# ...                 ...  ...
# b-100 O1            NaN  NaN
#       O2            NaN  NaN
#       F7            NaN  NaN
#       F8            NaN  NaN
#       T3            NaN  NaN
#       T4            NaN  NaN
#       T5            NaN  NaN
#       T6            NaN  NaN
#       Fz            NaN  NaN
#       Cz            NaN  NaN
#       Pz            NaN  NaN
# a-12  FP1           NaN  NaN
#       FP2           NaN  NaN
#       F3            NaN  NaN
#       F4            NaN  NaN
#       C3            NaN  NaN
#       C4            NaN  NaN
#       P3            NaN  NaN
#       P4            NaN  NaN
#       O1            NaN  NaN
#       O2            NaN  NaN
#       F7            NaN  NaN
#       F8            NaN  NaN
#       T3            NaN  NaN
#       T4            NaN  NaN
#       T5            NaN  NaN
#       T6            NaN  NaN
#       Fz            NaN  NaN
#       Cz            NaN  NaN
#       Pz            NaN  NaN
#
# [5054 rows x 20 columns]

# %%
file_name = 'durations.csv'
df = pd.read_csv(os.path.join(DURATIONS_ROOT, file_name), sep=' ', index_col=0)
str(df.groupby('sfreq').describe())
# Out:
# '       duration_s                                                            \\\n            count       mean        std     min       25%     50%       75%   \nsfreq                                                                         \n250.0       198.0  75.616202  19.994943  23.548  64.18200  72.508  82.98100   \n1000.0       68.0  79.519206  18.439587  48.841  63.72425  78.725  86.06975   \n\n                 \n            max  \nsfreq            \n250.0   170.840  \n1000.0  140.399  '
